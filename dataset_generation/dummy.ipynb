# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img_pth =r"C:\Users\Pintu\Downloads\archive\indoorCVPR_09\Images\toystore\toys_store_23_18_altavista.jpg"

# %%
img = cv2.imread(img_pth)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
ar_size = 0
ar_ang = 50
ar_pos = 0

h, w = img.shape[:2]

# %%
plt.imshow(img)

# %%
np.random.randint(0,255)
# Out:
# 212
