# %%
from ultralytics import YOLO
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import ultralytics

# %%
# check if YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.123  Python-3.10.11 torch-2.0.0+cpu CPU
# Setup complete  (12 CPUs, 15.8 GB RAM, 898.8/924.4 GB disk)

# %%
model = YOLO('yolov8n-pose.pt')  # load a pretrained model (recommended for training)

# %%
results = model.predict('https://ultralytics.com/images/bus.jpg')  # predict on an image
# Out:
# Found https:\ultralytics.com\images\bus.jpg locally at bus.jpg
# image 1/1 c:\Users\CMC\Documents\openposelibs\pose\DeepVision\ipy_notebooks\bus.jpg: 640x480 4 persons, 197.0ms
# Speed: 4.0ms preprocess, 197.0ms inference, 165.0ms postprocess per image at shape (1, 3, 640, 480)

# %%
plt.imshow(results[0].orig_img)

# %%
results[0].boxes.cls
# Out:
# tensor([0., 0., 0., 0.])

# %%
import polars as pl
